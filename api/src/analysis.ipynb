# %%
import pandas as pd
from IPython.display import display

# %%
df = pd.read_csv('../data/dados_covid.csv')

# %%
df.head()
# Out:
#         city  city_ibge_code        date  epidemiological_week  \
# 0     Abaíra       2900108.0  2020-07-13                    29
# 1      Abaré       2900207.0  2020-07-13                    29
# 2  Acajutiba       2900306.0  2020-07-13                    29
# 3   Adustina       2900355.0  2020-07-13                    29
# 4  Água Fria       2900405.0  2020-07-13                    29
#
#    estimated_population_2019  is_last  is_repeated  last_available_confirmed  \
# 0                     8739.0     True        False                         5
# 1                    20086.0     True        False                         5
# 2                    15159.0     True        False                        41
# 3                    17040.0     True        False                        47
# 4                    16970.0     True        False                        39
#
#    last_available_confirmed_per_100k_inhabitants last_available_date  \
# 0                                       57.21478          2020-07-13
# 1                                       24.89296          2020-07-13
# 2                                      270.46639          2020-07-13
# 3                                      275.82160          2020-07-13
# 4                                      229.81732          2020-07-13
#
#    last_available_death_rate  last_available_deaths  new_confirmed  \
# 0                     0.0000                      0              0
# 1                     0.0000                      0              0
# 2                     0.0488                      2              0
# 3                     0.0213                      1              3
# 4                     0.0256                      1              2
#
#    new_deaths  order_for_place place_type state
# 0           0               92       city    BA
# 1           0               60       city    BA
# 2           0               83       city    BA
# 3           0              101       city    BA
# 4           0               84       city    BA

# %%
cols = [
    'epidemiological_week', 'estimated_population_2019',
    'is_repeated', 'order_for_place', 'state'
]
temp = df.drop(cols, axis=1).copy()
display(temp[(temp['city'] == 'Candiba') & (temp['is_last'] == True)])

# Drop Importados cases
# temp = temp[temp['city'] != 'Importados/Indefinidos']
temp = temp.drop(temp[temp['city'] == 'Importados/Indefinidos'].index)
display(temp[temp['city'] == 'Candiba'].head())
# Out:
#        city  city_ibge_code        date  is_last  last_available_confirmed  \
# 76  Candiba       2906600.0  2020-07-13     True                        15
#
#     last_available_confirmed_per_100k_inhabitants last_available_date  \
# 76                                      104.75592          2020-07-13
#
#     last_available_death_rate  last_available_deaths  new_confirmed  \
# 76                        0.0                      0              0
#
#     new_deaths place_type
# 76           0       city
#          city  city_ibge_code        date  is_last  last_available_confirmed  \
# 76    Candiba       2906600.0  2020-07-13     True                        15
# 486   Candiba       2906600.0  2020-07-12    False                        15
# 896   Candiba       2906600.0  2020-07-11    False                        15
# 1305  Candiba       2906600.0  2020-07-10    False                        14
# 1714  Candiba       2906600.0  2020-07-09    False                        13
#
#       last_available_confirmed_per_100k_inhabitants last_available_date  \
# 76                                        104.75592          2020-07-13
# 486                                       104.75592          2020-07-12
# 896                                       104.75592          2020-07-11
# 1305                                       97.77219          2020-07-10
# 1714                                       90.78846          2020-07-09
#
#       last_available_death_rate  last_available_deaths  new_confirmed  \
# 76                          0.0                      0              0
# 486                         0.0                      0              0
# 896                         0.0                      0              1
# 1305                        0.0                      0              1
# 1714                        0.0                      0              0
#
#       new_deaths place_type
# 76             0       city
# 486            0       city
# 896            0       city
# 1305           0       city
# 1714           0       city
